# %% [markdown]
# # Neural Networks
#
# The following notebook shows some very basic neural network patterns.

# %% [markdown]
# ## Simple ANN
#
# The below composite processor represents an ANN which takes in an input vector X and two other vectors representing true values (repeated). The output is the mean squared error and weight adjustments happen inside the composite processor.

# %%
import json
from pybdp import load_project
from IPython.display import Markdown
from copy import deepcopy
from pprint import pprint

# Load the project JSON from file
with open("Neural Network.json", "r") as f:
    project_json = json.load(f)

# Load the project
project = load_project(project_json)


display(Markdown(project.processors_map["ANN Input-Sigmoid Epoch"].create_mermaid_graphic()[0]))
# Out:
# ```mermaid
# ---
# config:
#     layout: elk
# ---
# graph LR
# subgraph G0[ANN Input-Sigmoid Epoch - ANN Input-Sigmoid Epoch Block Block]
# direction LR
# X0[ANN Input-Sigmoid Epoch]
# subgraph G0P[Ports]
# direction TB
# XX0P0[Vector]
# XX0P1[Vector]
# XX0P2[Vector]
# end
# XX0P0[Vector] o--o X0
# XX0P1[Vector] o--o X0
# XX0P2[Vector] o--o X0
# subgraph G0T[Terminals]
# direction TB
# XX0T0[Floating Point Number]
# end
# X0 o--o XX0T0[Floating Point Number]
# end
#
# ```

# %% [markdown]
# ## Splitting to Forward and Backward Propagation
#
# By rendering the composite components we see how there is a forward and backward step and some of the activations from the forward step are used in the backward step.

# %%
display(Markdown(project.processors_map["ANN Input-Sigmoid Epoch"].create_mermaid_graphic_composite()[0]))
# Out:
# ```mermaid
# ---
# config:
#     layout: elk
# ---
# graph LR
# subgraph GC0[ANN Input-Sigmoid Epoch - ANN Input-Sigmoid Epoch Block Block]
# direction LR
# subgraph GS0[ANN Input-Sigmoid Epoch System]
# subgraph G1[ANN Input-Sigmoid Forward - ANN Input-Sigmoid Forward Block Block]
# direction LR
# X1[ANN Input-Sigmoid Forward]
# subgraph G1P[Ports]
# direction TB
# XX1P0[Vector]
# XX1P1[Vector]
# end
# XX1P0[Vector] o--o X1
# XX1P1[Vector] o--o X1
# subgraph G1T[Terminals]
# direction TB
# XX1T0[Floating Point Number]
# XX1T1[Vector]
# XX1T2[Vector]
# XX1T3[Vector]
# end
# X1 o--o XX1T0[Floating Point Number]
# X1 o--o XX1T1[Vector]
# X1 o--o XX1T2[Vector]
# X1 o--o XX1T3[Vector]
# end
# subgraph G2[ANN Input-Sigmoid Backpropagation - ANN Input-Sigmoid Backpropagation Block Block]
# direction LR
# X2[ANN Input-Sigmoid Backpropagation]
# subgraph G2P[Ports]
# direction TB
# XX2P0[Vector]
# XX2P1[Vector]
# XX2P2[Vector]
# XX2P3[Vector]
# end
# XX2P0[Vector] o--o X2
# ...

# %% [markdown]
# ## Even Deeper
#
# Let's jump into the subsystem and recursively render all the components of it, now we see how there are two layers, input and sigmoid.

# %%
display(Markdown(project.processors_map["ANN Input-Sigmoid Epoch"].subsystem.create_mermaid_graphic(recursive=True)[0]))
# Out:
# ```mermaid
# ---
# config:
#     layout: elk
# ---
# graph LR
# subgraph GS0[ANN Input-Sigmoid Epoch System]
# subgraph GC0[ANN Input-Sigmoid Forward - ANN Input-Sigmoid Forward Block Block]
# direction LR
# subgraph GS1[ANN Input-Sigmoid Forward System]
# subgraph G1[Basic Input Layer Forward - Input Layer Forward Block]
# direction LR
# X1[Basic Input Layer Forward]
# subgraph G1P[Ports]
# direction TB
# XX1P0[Vector]
# end
# XX1P0[Vector] o--o X1
# subgraph G1T[Terminals]
# direction TB
# XX1T0[Vector]
# end
# X1 o--o XX1T0[Vector]
# end
# subgraph G2[Sigmoid Hidden Layer 1 Forward - Sigmoid Layer Forward Block]
# direction LR
# X2[Sigmoid Hidden Layer 1 Forward]
# subgraph G2P[Ports]
# direction TB
# XX2P0[Vector]
# end
# XX2P0[Vector] o--o X2
# subgraph G2T[Terminals]
# direction TB
# XX2T0[Vector]
# end
# X2 o--o XX2T0[Vector]
# end
# subgraph G3[Mean Squared Error - Calculate Loss Block]
# direction LR
# X3[Mean Squared Error]
# subgraph G3P[Ports]
# direction TB
# ...

# %% [markdown]
# ## Individual Systems
#
# We can also view the individual systems on their own below

# %%
display(Markdown(project.processors_map["ANN Input-Sigmoid Forward"].create_mermaid_graphic_composite()[0]))
# Out:
# ```mermaid
# ---
# config:
#     layout: elk
# ---
# graph LR
# subgraph GC0[ANN Input-Sigmoid Forward - ANN Input-Sigmoid Forward Block Block]
# direction LR
# subgraph GS0[ANN Input-Sigmoid Forward System]
# subgraph G1[Basic Input Layer Forward - Input Layer Forward Block]
# direction LR
# X1[Basic Input Layer Forward]
# subgraph G1P[Ports]
# direction TB
# XX1P0[Vector]
# end
# XX1P0[Vector] o--o X1
# subgraph G1T[Terminals]
# direction TB
# XX1T0[Vector]
# end
# X1 o--o XX1T0[Vector]
# end
# subgraph G2[Sigmoid Hidden Layer 1 Forward - Sigmoid Layer Forward Block]
# direction LR
# X2[Sigmoid Hidden Layer 1 Forward]
# subgraph G2P[Ports]
# direction TB
# XX2P0[Vector]
# end
# XX2P0[Vector] o--o X2
# subgraph G2T[Terminals]
# direction TB
# XX2T0[Vector]
# end
# X2 o--o XX2T0[Vector]
# end
# subgraph G3[Mean Squared Error - Calculate Loss Block]
# direction LR
# X3[Mean Squared Error]
# subgraph G3P[Ports]
# direction TB
# XX3P0[Vector]
# XX3P1[Vector]
# end
# ...

# %%
display(Markdown(project.processors_map["ANN Input-Sigmoid Backpropagation"].create_mermaid_graphic_composite()[0]))
# Out:
# ```mermaid
# ---
# config:
#     layout: elk
# ---
# graph LR
# subgraph GC0[ANN Input-Sigmoid Backpropagation - ANN Input-Sigmoid Backpropagation Block Block]
# direction LR
# subgraph GS0[ANN Input-Sigmoid Backpropagation System]
# subgraph G1[Mean Squared Error Derivative - Loss Function Derivative Block]
# direction LR
# X1[Mean Squared Error Derivative]
# subgraph G1P[Ports]
# direction TB
# XX1P0[Vector]
# XX1P1[Vector]
# end
# XX1P0[Vector] o--o X1
# XX1P1[Vector] o--o X1
# subgraph G1T[Terminals]
# direction TB
# XX1T0[Vector]
# end
# X1 o--o XX1T0[Vector]
# end
# subgraph G2[Sigmoid Hidden Layer 1 Backpropagation - Sigmoid Layer Backpropagation Block]
# direction LR
# X2[Sigmoid Hidden Layer 1 Backpropagation]
# subgraph G2P[Ports]
# direction TB
# XX2P0[Vector]
# XX2P1[Vector]
# end
# XX2P0[Vector] o--o X2
# XX2P1[Vector] o--o X2
# subgraph G2T[Terminals]
# direction TB
# XX2T0[Vector]
# end
# X2 o--o XX2T0[Vector]
# end
# ...
